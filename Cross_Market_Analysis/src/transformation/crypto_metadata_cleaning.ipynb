# %%
# Bootstrap the directory
# %run "F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\bootstrap.py"

# %%
# Import the libraries
import pandas as pd
from src.config.settings import (Crypto_Metadata_Columns)

# %%
# Load the raw data
df = pd.read_csv("F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\Cross-Market Data\\raw\\crypto\\coin_list.csv")

# %% [markdown]
# # Filter required columns

# %%
# define required columns
required_cols = ["id", "symbol", "name", "current_price", "market_cap", "market_cap_rank", "total_volume", "circulating_supply", "total_supply", "ath" , "atl", "last_updated"]

meta_columns = Crypto_Metadata_Columns

# %%
# filter columns
df1 = df.loc[:, required_cols]
df2 = df.loc[:, meta_columns]

# %% [markdown]
# # Rename columns for SQL

# %%
df1 = df1.rename(columns = {"last_updated" : "timestamp"})
df2
# Out:
#                      id symbol           name     market_cap  market_cap_rank
# 0               bitcoin    btc        Bitcoin  1773542722104                1
# 1              ethereum    eth       Ethereum   354173986486                2
# 2                tether   usdt         Tether   186620060068                3
# 3           binancecoin    bnb            BNB   119835240169                4
# 4                ripple    xrp            XRP   115311046701                5
# ...                 ...    ...            ...            ...              ...
# 1245  alpha-quark-token    aqt    Alpha Quark       17172947             1246
# 1246      yieldfi-vyusd  vyusd  YieldFi vyUSD       16945870             1247
# 1247           alchemix   alcx       Alchemix       16996489             1248
# 1248          treehouse   tree      Treehouse       16928278             1249
# 1249          goldfinch    gfi      Goldfinch       16888165             1250
#
# [1250 rows x 5 columns]

# %% [markdown]
# # Edit Date & Time Stamp

# %%
df1[['date', 'time']] = df1['timestamp'].str.split('T', expand = True)

# %%
df1.drop(['timestamp', 'time'], axis = 1, inplace = True)

# %%
# Out:
# Raw rows:  1250

# %% [markdown]
# # Save to a Pickle

# %%
df1.to_pickle("F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\Cross-Market Data\\raw\\crypto\\processed_df.pkl")

# %%
df2.to_pickle("F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\Cross-Market Data\\raw\\crypto\\processed_df_meta.pkl")
