# %%
# %run "F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\bootstrap.py"

# %%
from src.config.settings import (Oil_Data_Source, WTI_URL)
import pandas as pd

# %% [markdown]
# # Load CSV from GitHub

# %%
def oil_data():
    url = f"{WTI_URL}"
    df = pd.read_csv(url)
    return df

df_oil = oil_data()

# %%
df_oil.head()
# Out:
#          Date  Price
# 0  1986-01-02  25.56
# 1  1986-01-03  26.00
# 2  1986-01-06  26.53
# 3  1986-01-07  25.85
# 4  1986-01-08  25.87

# %%
df_oil.tail()
# Out:
#              Date  Price
# 10076  2026-01-13  60.85
# 10077  2026-01-14  61.84
# 10078  2026-01-15  59.13
# 10079  2026-01-16  59.40
# 10080  2026-01-20  60.30

# %%
# Export DataFrame to CSV
df_oil.to_csv("F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\Cross-Market Data\\raw\\oil\\oil_prices.csv")
