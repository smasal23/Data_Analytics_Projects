# %%
# Run the bootstrap
# %run "F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\bootstrap.py"

# %% [markdown]
# # Import Libraries and Modules

# %%
import requests
import pandas as pd
from src.config.settings import (Coingecko_Base_URL, Coingecko_Market_Endpoint, Coingecko_VS_Currency, Coingecko_Per_Page, Coingecko_Order)

# %% [markdown]
# # Call CoinGecko markets API

# %%
url = f"{Coingecko_Base_URL}{Coingecko_Market_Endpoint}"

# %%
parameters = {
    "vs_currency" : Coingecko_VS_Currency,
    "order" : Coingecko_Order,
    "per_page" : Coingecko_Per_Page,
    "page" : 1,
    "sparkline" : False
    }

# %% [markdown]
# # Store raw JSON response

# %%
CG_markets_1 = []
for page in range(1, 4):
    parameters["page"] = page
    response = requests.get(url, parameters)
    data = response.json()
    CG_markets_1.extend(data)

# %%
CG_markets_2 = []
for page in range(4, 6):
    parameters["page"] = page
    response = requests.get(url, parameters)
    data = response.json()
    CG_markets_2.extend(data)

# %%
# Merge the two lists while deduplicating by comprehending the dictionaries upon addition.
# CG_markets = list({i["id"] : i for i in CG_markets_1 + CG_markets_2}.values())
CG_markets = list({
    i["id"]: i
    for i in (CG_markets_1 + CG_markets_2)
    if isinstance(i, dict) and "id" in i
}.values())

# %% [markdown]
# # Convert into Dataframe

# %%
df = pd.DataFrame(CG_markets)
raw_CG_markets = df.sort_values("market_cap_rank")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.DataFrame(CG_markets)
#       2 raw_CG_markets = df.sort_values("market_cap_rank")
#
# NameError: name 'CG_markets' is not defined

# %%
raw_CG_markets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1250 entries, 0 to 1249
# Data columns (total 26 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1250 non-null   object
#  1   symbol                            1250 non-null   object
#  2   name                              1250 non-null   object
#  3   image                             1250 non-null   object
#  4   current_price                     1250 non-null   float64
#  5   market_cap                        1250 non-null   int64
#  6   market_cap_rank                   1250 non-null   int64
#  7   fully_diluted_valuation           1248 non-null   float64
#  8   total_volume                      1250 non-null   float64
#  9   high_24h                          1231 non-null   float64
#  10  low_24h                           1231 non-null   float64
#  11  price_change_24h                  1231 non-null   float64
#  12  price_change_percentage_24h       1231 non-null   float64
#  13  market_cap_change_24h             1230 non-null   float64
#  14  market_cap_change_percentage_24h  1230 non-null   float64
#  15  circulating_supply                1250 non-null   float64
#  16  total_supply                      1248 non-null   float64
#  17  max_supply                        673 non-null    float64
#  18  ath                               1250 non-null   float64
#  19  ath_change_percentage             1250 non-null   float64
#  20  ath_date                          1250 non-null   object
#  21  atl                               1250 non-null   float64
#  22  atl_change_percentage             1250 non-null   float64
#  23  atl_date                          1250 non-null   object
#  24  roi                               86 non-null     object
#  25  last_updated                      1250 non-null   object
# dtypes: float64(16), int64(2), object(8)
# memory usage: 263.7+ KB

# %%
raw_CG_markets.head()
# Out:
#             id symbol      name  \
# 0      bitcoin    btc   Bitcoin
# 1     ethereum    eth  Ethereum
# 2       tether   usdt    Tether
# 3  binancecoin    bnb       BNB
# 4       ripple    xrp       XRP
#
#                                                image  current_price  \
# 0  https://coin-images.coingecko.com/coins/images...   88692.000000
# 1  https://coin-images.coingecko.com/coins/images...    2930.660000
# 2  https://coin-images.coingecko.com/coins/images...       0.998506
# 3  https://coin-images.coingecko.com/coins/images...     877.810000
# 4  https://coin-images.coingecko.com/coins/images...       1.890000
#
#       market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0  1773542722104                1             1.773543e+12  2.023879e+10
# 1   354173986486                2             3.541740e+11  9.130872e+09
# 2   186620060068                3             1.920788e+11  3.694953e+10
# 3   119835240169                4             1.198352e+11  6.202527e+08
# 4   115311046701                5             1.894634e+11  1.243312e+09
#
#        high_24h  ...  total_supply    max_supply        ath  \
# 0  89367.000000  ...  1.998041e+07  2.100000e+07  126080.00
# 1   2963.170000  ...  1.206944e+08           NaN    4946.05
# 2      0.998632  ...  1.923683e+11           NaN       1.32
# 3    891.130000  ...  1.363605e+08  2.000000e+08    1369.99
# 4      1.920000  ...  9.998572e+10  1.000000e+11       3.65
#
#    ath_change_percentage                  ath_date        atl  \
# 0              -29.65377  2025-10-06T18:57:42.558Z  67.810000
# 1              -40.74745  2025-08-24T19:21:03.333Z   0.432979
# 2              -24.53246  2018-07-24T00:00:00.000Z   0.572521
# 3              -35.92622  2025-10-13T08:41:24.131Z   0.039818
# 4              -48.10849  2025-07-18T03:40:53.808Z   0.002686
#
#    atl_change_percentage                  atl_date  \
# 0           1.306974e+05  2013-07-06T00:00:00.000Z
# 1           6.767598e+05  2015-10-20T00:00:00.000Z
# 2           7.440538e+01  2015-03-02T00:00:00.000Z
# 3           2.204461e+06  2017-10-19T00:00:00.000Z
# 4           7.033988e+04  2014-05-22T00:00:00.000Z
#
#                                                  roi              last_updated
# 0                                               None  2026-01-25T14:22:45.420Z
# 1  {'times': 43.171984503572276, 'currency': 'btc...  2026-01-25T14:22:53.543Z
# 2                                               None  2026-01-25T14:22:49.178Z
# 3                                               None  2026-01-25T14:22:45.903Z
# 4                                               None  2026-01-25T14:22:49.075Z
#
# [5 rows x 26 columns]

# %%
raw_CG_markets.isnull().sum()
# Out:
# id                                     0
# symbol                                 0
# name                                   0
# image                                  0
# current_price                          0
# market_cap                             0
# market_cap_rank                        0
# fully_diluted_valuation                2
# total_volume                           0
# high_24h                              19
# low_24h                               19
# price_change_24h                      19
# price_change_percentage_24h           19
# market_cap_change_24h                 20
# market_cap_change_percentage_24h      20
# circulating_supply                     0
# total_supply                           2
# max_supply                           577
# ath                                    0
# ath_change_percentage                  0
# ath_date                               0
# atl                                    0
# atl_change_percentage                  0
# atl_date                               0
# roi                                 1164
# last_updated                           0
# dtype: int64

# %%
raw_CG_markets.columns
# Out:
# Index(['id', 'symbol', 'name', 'image', 'current_price', 'market_cap',
#        'market_cap_rank', 'fully_diluted_valuation', 'total_volume',
#        'high_24h', 'low_24h', 'price_change_24h',
#        'price_change_percentage_24h', 'market_cap_change_24h',
#        'market_cap_change_percentage_24h', 'circulating_supply',
#        'total_supply', 'max_supply', 'ath', 'ath_change_percentage',
#        'ath_date', 'atl', 'atl_change_percentage', 'atl_date', 'roi',
#        'last_updated'],
#       dtype='object')

# %%
print("Raw rows: ", len(raw_CG_markets))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print("Raw rows: ", len(raw_CG_markets))
#
# NameError: name 'raw_CG_markets' is not defined

# %% [markdown]
# # Export Dataframe to CSV

# %%
raw_CG_markets.to_csv("F:\\onedrive\\Desktop\\DATA SCIENCE\\Project 1\\Cross-Market Analysis\\Cross-Market Data\\raw\\crypto\\coin_list.csv")
